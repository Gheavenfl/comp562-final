# %%
# import libraries
import pandas as pd
import random
from sklearn.feature_extraction.text import CountVectorizer
# read csv file, generate list and messages as seperate labels
df = pd.read_csv ('spam.csv', encoding = "ISO-8859-1", usecols=[0, 1])
labels = df['v1'].tolist()
label_transform = {"ham": 0, 'spam': 1}
labels = [label_transform[label] for label in labels]
messages = df['v2'].tolist()

# bag of words representation
bow_vectorizer = CountVectorizer(stop_words='english')
bow_messages = bow_vectorizer.fit_transform(messages).todense()
bow_messages = [b.tolist()[0] for b in bow_messages]

# seperate dataset into training set and validation set
all_indexs = [i for i in range(len(labels))]

# choose 75% of messages 
training_indexs = random.sample(all_indexs, k=int(len(labels)*0.75))
validation_indexs = list(set(all_indexs) - set(training_indexs))
training_labels = [labels[i] for i in training_indexs]
training_messages = [bow_messages[i] for i in training_indexs]
validation_labels = [labels[i] for i in validation_indexs]
validation_messages = [bow_messages[i] for i in validation_indexs]

print('number of messages: ', len(bow_messages))
print('number of training mesaages: ', len(training_messages))
print('number of validation messages: ', len(validation_messages))
# Out:
# number of messages:  5572
# number of training mesaages:  4179
# number of validation messages:  1393

# %%
import random
import math

def sub_sampling(dataset, sample_len):
    sample = []
    while len(sample) < sample_len:
        index = random.randrange(len(dataset))
        sample.append(dataset[index])
    return sample

def gini_impurity(nodes, all_labels):
    # calculate the weighted sum of gini impurity for all the nodes
    total_number_of_samples = float(sum([len(node) for node in nodes]))
    gini_impurity = 0.0
    for node in nodes:
        node_size = len(node)
        if node_size == 0:
            continue
        score = 1.0
        node_labels = [n[-1] for n in node]
        for label in all_labels:
            possibility = node_labels.count(label) / node_size
            score -= possibility ** 2
        gini_impurity += score * (node_size / total_number_of_samples)
    return gini_impurity

def train_tree_helper(node, min_size, max_depth, features_to_split, current_depth):
    left, right = node['nodes']
    del(node['nodes'])
    if not left or not right:
        # no longer splittable
        node['left'] = node['right'] = dominating_label(left + right)
        return
    if current_depth > max_depth:
        node['left'] = dominating_label(left)
        node['right'] = dominating_label(right)
        return
    if len(left) <= min_size:
        node['left'] = dominating_label(left)
    else:
        node['left'] = choose_split(left, features_to_split)
        train_tree_helper(node['left'], min_size, max_depth, features_to_split, current_depth+1)
    if len(right) <= min_size:
        node['right'] = dominating_label(right)
    else:
        node['right'] =  choose_split(right, features_to_split)
        train_tree_helper(node['right'], min_size, max_depth, features_to_split, current_depth+1)

def train_tree(sample_set, min_size, max_depth, num_features):
    # train individual trees in the forst
    print("training")
    all_features = [i for i in range(len(sample_set[0])-1)]
    features_to_split = random.sample(all_features, num_features)
    tree_root = choose_split(sample_set, features_to_split)
    train_tree_helper(tree_root, min_size, max_depth, features_to_split, 1)
    return tree_root

def split_data(sample_set, feature_ind, val):
    left = [sample for sample in sample_set if sample[feature_ind] < val]
    right = [sample for sample in sample_set if sample[feature_ind] >= val]
    return (left, right)

def choose_split(sample_set, features_to_split):
    all_labels = list(set([sample[-1] for sample in sample_set]))
    final_splitting_index = None
    final_splitting_val = None
    final_splitting_nodes = None
    best_score = math.inf
    for feature in features_to_split:
        splitting_vals = set([s[feature] for s in sample_set])
        for splitting_val in splitting_vals:
            nodes = split_data(sample_set, feature, splitting_val)
            gini_score = gini_impurity(nodes, all_labels)
            if gini_score < best_score:
                final_splitting_index = feature
                final_splitting_val = splitting_val
                final_splitting_nodes = nodes
                best_score = gini_score
    return {'index': final_splitting_index, 'val': final_splitting_val, 'nodes':final_splitting_nodes}

def dominating_label(sample_set):
    labels = [sample[-1] for sample in sample_set]
    return max(set(labels), key = labels.count)
    

def treePrediction(sample, tree):
    if sample[tree['index']] < tree['val']:
        # left
        if isinstance(tree['left'], dict):
            return treePrediction(sample, tree['left'])
        else:
            return tree['left']
    else:
        if isinstance(tree['right'], dict):
            return treePrediction(sample, tree['right'])
        else:
            return tree['right']
        
def multipleTreesPrediction(sample, trees):
    predictions = []
    for tree in trees:
        predictions.append(treePrediction(sample, tree))
    return max(set(predictions), key = predictions.count)

def randomForest(train_set,train_label, min_size, max_depth, num_trees, num_features, sample_size):
    # train_set -> the training data
    # min_size -> the minimum number of samples in a non-terminal node
    # max_depth -> the maximize number of layers of the tree
    # num_trees -> number of sub-trees to train
    # num_features -> number of features to split on 
    # sample_size -> the size of the sub-sample we create for each tree
    padded_train_set = [train_set[i] + [train_label[i]] for i in range(len(train_set))]
    trees = []
    for i in range(num_trees):
        print('generating tree: ', i)
        sub_sample = sub_sampling(padded_train_set, sample_size)
        new_tree = train_tree(sub_sample, min_size, max_depth, num_features)
        trees.append(new_tree)
    return trees

# %%
trees = randomForest(training_messages, training_labels, 2, 50, 10, 2000, 1000)
# Out:
# generating tree:  0
# training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-88c365decbf6> in <module>
# ----> 1 trees = randomForest(training_messages, training_labels, 2, 50, 10, 2000, 1000)
#
# <ipython-input-6-1b5ffe63fe0f> in randomForest(train_set, train_label, min_size, max_depth, num_trees, num_features, sample_size)
#     116         print('generating tree: ', i)
#     117         sub_sample = sub_sampling(padded_train_set, sample_size)
# --> 118         new_tree = train_tree(sub_sample, min_size, max_depth, num_features)
#     119         trees.append(new_tree)
#     120     return trees
#
# <ipython-input-6-1b5ffe63fe0f> in train_tree(sample_set, min_size, max_depth, num_features)
#      54     features_to_split = random.sample(all_features, num_features)
#      55     tree_root = choose_split(sample_set, features_to_split)
# ---> 56     train_tree_helper(tree_root, min_size, max_depth, features_to_split, 1)
#      57     return tree_root
#      58
#
# <ipython-input-6-1b5ffe63fe0f> in train_tree_helper(node, min_size, max_depth, features_to_split, current_depth)
#      41     else:
#      42         node['left'] = choose_split(left, features_to_split)
# ---> 43         train_tree_helper(node['left'], min_size, max_depth, features_to_split, current_depth+1)
#      44     if len(right) <= min_size:
#      45         node['right'] = dominating_label(right)
#
# <ipython-input-6-1b5ffe63fe0f> in train_tree_helper(node, min_size, max_depth, features_to_split, current_depth)
#      41     else:
#      42         node['left'] = choose_split(left, features_to_split)
# ---> 43         train_tree_helper(node['left'], min_size, max_depth, features_to_split, current_depth+1)
#      44     if len(right) <= min_size:
#      45         node['right'] = dominating_label(right)
#
# <ipython-input-6-1b5ffe63fe0f> in train_tree_helper(node, min_size, max_depth, features_to_split, current_depth)
#      41     else:
#      42         node['left'] = choose_split(left, features_to_split)
# ---> 43         train_tree_helper(node['left'], min_size, max_depth, features_to_split, current_depth+1)
#      44     if len(right) <= min_size:
#      45         node['right'] = dominating_label(right)
#
# <ipython-input-6-1b5ffe63fe0f> in train_tree_helper(node, min_size, max_depth, features_to_split, current_depth)
#      40         node['left'] = dominating_label(left)
#      41     else:
# ---> 42         node['left'] = choose_split(left, features_to_split)
#      43         train_tree_helper(node['left'], min_size, max_depth, features_to_split, current_depth+1)
#      44     if len(right) <= min_size:
#
# <ipython-input-6-1b5ffe63fe0f> in choose_split(sample_set, features_to_split)
#      69     best_score = math.inf
#      70     for feature in features_to_split:
# ---> 71         splitting_vals = set([s[feature] for s in sample_set])
#      72         for splitting_val in splitting_vals:
#      73             nodes = split_data(sample_set, feature, splitting_val)
#
# <ipython-input-6-1b5ffe63fe0f> in <listcomp>(.0)
#      69     best_score = math.inf
#      70     for feature in features_to_split:
# ---> 71         splitting_vals = set([s[feature] for s in sample_set])
#      72         for splitting_val in splitting_vals:
#      73             nodes = split_data(sample_set, feature, splitting_val)
#
# KeyboardInterrupt:

# %%
re = []
for i, sample in enumerate(validation_messages):
    print("processing message: ", i)
    re.append(multipleTreesPrediction(sample, trees))
    
print(len(re))
# Out:
# processing message:  0
# processing message:  1
# processing message:  2
# processing message:  3
# processing message:  4
# processing message:  5
# processing message:  6
# processing message:  7
# processing message:  8
# processing message:  9
# processing message:  10
# processing message:  11
# processing message:  12
# processing message:  13
# processing message:  14
# processing message:  15
# processing message:  16
# processing message:  17
# processing message:  18
# processing message:  19
# processing message:  20
# processing message:  21
# processing message:  22
# processing message:  23
# processing message:  24
# processing message:  25
# processing message:  26
# processing message:  27
# processing message:  28
# processing message:  29
# processing message:  30
# processing message:  31
# processing message:  32
# processing message:  33
# processing message:  34
# processing message:  35
# processing message:  36
# processing message:  37
# processing message:  38
# processing message:  39
# processing message:  40
# processing message:  41
# processing message:  42
# processing message:  43
# processing message:  44
# processing message:  45
# processing message:  46
# processing message:  47
# processing message:  48
# processing message:  49
# processing message:  50
# processing message:  51
# processing message:  52
# processing message:  53
# processing message:  54
# processing message:  55
# processing message:  56
# processing message:  57
# processing message:  58
# processing message:  59
# processing message:  60
# processing message:  61
# processing message:  62
# processing message:  63
# processing message:  64
# processing message:  65
# processing message:  66
# processing message:  67
# processing message:  68
# processing message:  69
# processing message:  70
# processing message:  71
# processing message:  72
# processing message:  73
# processing message:  74
# processing message:  75
# processing message:  76
# processing message:  77
# processing message:  78
# processing message:  79
# processing message:  80
# processing message:  81
# processing message:  82
# processing message:  83
# processing message:  84
# processing message:  85
# processing message:  86
# processing message:  87
# processing message:  88
# processing message:  89
# processing message:  90
# processing message:  91
# processing message:  92
# processing message:  93
# processing message:  94
# processing message:  95
# processing message:  96
# processing message:  97
# processing message:  98
# processing message:  99
# processing message:  100
# processing message:  101
# processing message:  102
# processing message:  103
# processing message:  104
# processing message:  105
# processing message:  106
# processing message:  107
# processing message:  108
# processing message:  109
# processing message:  110
# processing message:  111
# processing message:  112
# processing message:  113
# processing message:  114
# processing message:  115
# processing message:  116
# processing message:  117
# processing message:  118
# processing message:  119
# processing message:  120
# processing message:  121
# processing message:  122
# processing message:  123
# processing message:  124
# processing message:  125
# processing message:  126
# processing message:  127
# processing message:  128
# processing message:  129
# processing message:  130
# processing message:  131
# processing message:  132
# processing message:  133
# processing message:  134
# processing message:  135
# processing message:  136
# processing message:  137
# processing message:  138
# processing message:  139
# processing message:  140
# processing message:  141
# processing message:  142
# processing message:  143
# processing message:  144
# processing message:  145
# processing message:  146
# processing message:  147
# processing message:  148
# processing message:  149
# processing message:  150
# processing message:  151
# processing message:  152
# processing message:  153
# processing message:  154
# processing message:  155
# processing message:  156
# processing message:  157
# processing message:  158
# processing message:  159
# processing message:  160
# processing message:  161
# processing message:  162
# processing message:  163
# processing message:  164
# processing message:  165
# processing message:  166
# processing message:  167
# processing message:  168
# processing message:  169
# processing message:  170
# processing message:  171
# processing message:  172
# processing message:  173
# processing message:  174
# processing message:  175
# processing message:  176
# processing message:  177
# processing message:  178
# processing message:  179
# processing message:  180
# processing message:  181
# processing message:  182
# processing message:  183
# processing message:  184
# processing message:  185
# processing message:  186
# processing message:  187
# processing message:  188
# processing message:  189
# processing message:  190
# processing message:  191
# processing message:  192
# processing message:  193
# processing message:  194
# processing message:  195
# processing message:  196
# processing message:  197
# processing message:  198
# processing message:  199
# processing message:  200
# processing message:  201
# processing message:  202
# processing message:  203
# processing message:  204
# processing message:  205
# processing message:  206
# processing message:  207
# processing message:  208
# processing message:  209
# processing message:  210
# processing message:  211
# processing message:  212
# processing message:  213
# processing message:  214
# processing message:  215
# processing message:  216
# processing message:  217
# processing message:  218
# processing message:  219
# processing message:  220
# processing message:  221
# processing message:  222
# processing message:  223
# processing message:  224
# processing message:  225
# processing message:  226
# processing message:  227
# processing message:  228
# processing message:  229
# processing message:  230
# processing message:  231
# processing message:  232
# processing message:  233
# processing message:  234
# processing message:  235
# processing message:  236
# processing message:  237
# processing message:  238
# processing message:  239
# processing message:  240
# processing message:  241
# processing message:  242
# processing message:  243
# processing message:  244
# processing message:  245
# processing message:  246
# processing message:  247
# processing message:  248
# processing message:  249
# processing message:  250
# processing message:  251
# processing message:  252
# processing message:  253
# processing message:  254
# processing message:  255
# processing message:  256
# processing message:  257
# processing message:  258
# processing message:  259
# processing message:  260
# processing message:  261
# processing message:  262
# processing message:  263
# processing message:  264
# processing message:  265
# processing message:  266
# processing message:  267
# processing message:  268
# processing message:  269
# processing message:  270
# processing message:  271
# processing message:  272
# processing message:  273
# processing message:  274
# processing message:  275
# processing message:  276
# processing message:  277
# processing message:  278
# processing message:  279
# processing message:  280
# processing message:  281
# processing message:  282
# processing message:  283
# processing message:  284
# processing message:  285
# processing message:  286
# processing message:  287
# processing message:  288
# processing message:  289
# processing message:  290
# processing message:  291
# processing message:  292
# processing message:  293
# processing message:  294
# processing message:  295
# processing message:  296
# processing message:  297
# processing message:  298
# processing message:  299
# processing message:  300
# processing message:  301
# processing message:  302
# processing message:  303
# processing message:  304
# processing message:  305
# processing message:  306
# processing message:  307
# processing message:  308
# processing message:  309
# processing message:  310
# processing message:  311
# processing message:  312
# processing message:  313
# processing message:  314
# processing message:  315
# processing message:  316
# processing message:  317
# processing message:  318
# processing message:  319
# processing message:  320
# processing message:  321
# processing message:  322
# processing message:  323
# processing message:  324
# processing message:  325
# processing message:  326
# processing message:  327
# processing message:  328
# processing message:  329
# processing message:  330
# processing message:  331
# processing message:  332
# processing message:  333
# processing message:  334
# processing message:  335
# processing message:  336
# processing message:  337
# processing message:  338
# processing message:  339
# processing message:  340
# processing message:  341
# processing message:  342
# processing message:  343
# processing message:  344
# processing message:  345
# processing message:  346
# processing message:  347
# processing message:  348
# processing message:  349
# processing message:  350
# processing message:  351
# processing message:  352
# processing message:  353
# processing message:  354
# processing message:  355
# processing message:  356
# processing message:  357
# processing message:  358
# processing message:  359
# processing message:  360
# processing message:  361
# processing message:  362
# processing message:  363
# processing message:  364
# processing message:  365
# processing message:  366
# processing message:  367
# processing message:  368
# processing message:  369
# processing message:  370
# processing message:  371
# processing message:  372
# processing message:  373
# processing message:  374
# processing message:  375
# processing message:  376
# processing message:  377
# processing message:  378
# processing message:  379
# processing message:  380
# processing message:  381
# processing message:  382
# processing message:  383
# processing message:  384
# processing message:  385
# processing message:  386
# processing message:  387
# processing message:  388
# processing message:  389
# processing message:  390
# processing message:  391
# processing message:  392
# processing message:  393
# processing message:  394
# processing message:  395
# processing message:  396
# processing message:  397
# processing message:  398
# processing message:  399
# processing message:  400
# processing message:  401
# processing message:  402
# processing message:  403
# processing message:  404
# processing message:  405
# processing message:  406
# processing message:  407
# processing message:  408
# processing message:  409
# processing message:  410
# processing message:  411
# processing message:  412
# processing message:  413
# processing message:  414
# processing message:  415
# processing message:  416
# processing message:  417
# processing message:  418
# processing message:  419
# processing message:  420
# processing message:  421
# processing message:  422
# processing message:  423
# processing message:  424
# processing message:  425
# processing message:  426
# processing message:  427
# processing message:  428
# processing message:  429
# processing message:  430
# processing message:  431
# processing message:  432
# processing message:  433
# processing message:  434
# processing message:  435
# processing message:  436
# processing message:  437
# processing message:  438
# processing message:  439
# processing message:  440
# processing message:  441
# processing message:  442
# processing message:  443
# processing message:  444
# processing message:  445
# processing message:  446
# processing message:  447
# processing message:  448
# processing message:  449
# processing message:  450
# processing message:  451
# processing message:  452
# processing message:  453
# processing message:  454
# processing message:  455
# processing message:  456
# processing message:  457
# processing message:  458
# processing message:  459
# processing message:  460
# processing message:  461
# processing message:  462
# processing message:  463
# processing message:  464
# processing message:  465
# processing message:  466
# processing message:  467
# processing message:  468
# processing message:  469
# processing message:  470
# processing message:  471
# processing message:  472
# processing message:  473
# processing message:  474
# processing message:  475
# processing message:  476
# processing message:  477
# processing message:  478
# processing message:  479
# processing message:  480
# processing message:  481
# processing message:  482
# processing message:  483
# processing message:  484
# processing message:  485
# processing message:  486
# processing message:  487
# processing message:  488
# processing message:  489
# processing message:  490
# processing message:  491
# processing message:  492
# processing message:  493
# processing message:  494
# processing message:  495
# processing message:  496
# processing message:  497
# processing message:  498
# processing message:  499
# processing message:  500
# processing message:  501
# processing message:  502
# processing message:  503
# processing message:  504
# processing message:  505
# processing message:  506
# processing message:  507
# processing message:  508
# processing message:  509
# processing message:  510
# processing message:  511
# processing message:  512
# processing message:  513
# processing message:  514
# processing message:  515
# processing message:  516
# processing message:  517
# processing message:  518
# processing message:  519
# processing message:  520
# processing message:  521
# processing message:  522
# processing message:  523
# processing message:  524
# processing message:  525
# processing message:  526
# processing message:  527
# processing message:  528
# processing message:  529
# processing message:  530
# processing message:  531
# processing message:  532
# processing message:  533
# processing message:  534
# processing message:  535
# processing message:  536
# processing message:  537
# processing message:  538
# processing message:  539
# processing message:  540
# processing message:  541
# processing message:  542
# processing message:  543
# processing message:  544
# processing message:  545
# processing message:  546
# processing message:  547
# processing message:  548
# processing message:  549
# processing message:  550
# processing message:  551
# processing message:  552
# processing message:  553
# processing message:  554
# processing message:  555
# processing message:  556
# processing message:  557
# processing message:  558
# processing message:  559
# processing message:  560
# processing message:  561
# processing message:  562
# processing message:  563
# processing message:  564
# processing message:  565
# processing message:  566
# processing message:  567
# processing message:  568
# processing message:  569
# processing message:  570
# processing message:  571
# processing message:  572
# processing message:  573
# processing message:  574
# processing message:  575
# processing message:  576
# processing message:  577
# processing message:  578
# processing message:  579
# processing message:  580
# processing message:  581
# processing message:  582
# processing message:  583
# processing message:  584
# processing message:  585
# processing message:  586
# processing message:  587
# processing message:  588
# processing message:  589
# processing message:  590
# processing message:  591
# processing message:  592
# processing message:  593
# processing message:  594
# processing message:  595
# processing message:  596
# processing message:  597
# processing message:  598
# processing message:  599
# processing message:  600
# processing message:  601
# processing message:  602
# processing message:  603
# processing message:  604
# processing message:  605
# processing message:  606
# processing message:  607
# processing message:  608
# processing message:  609
# processing message:  610
# processing message:  611
# processing message:  612
# processing message:  613
# processing message:  614
# processing message:  615
# processing message:  616
# processing message:  617
# processing message:  618
# processing message:  619
# processing message:  620
# processing message:  621
# processing message:  622
# processing message:  623
# processing message:  624
# processing message:  625
# processing message:  626
# processing message:  627
# processing message:  628
# processing message:  629
# processing message:  630
# processing message:  631
# processing message:  632
# processing message:  633
# processing message:  634
# processing message:  635
# processing message:  636
# processing message:  637
# processing message:  638
# processing message:  639
# processing message:  640
# processing message:  641
# processing message:  642
# processing message:  643
# processing message:  644
# processing message:  645
# processing message:  646
# processing message:  647
# processing message:  648
# processing message:  649
# processing message:  650
# processing message:  651
# processing message:  652
# processing message:  653
# processing message:  654
# processing message:  655
# processing message:  656
# processing message:  657
# processing message:  658
# processing message:  659
# processing message:  660
# processing message:  661
# processing message:  662
# processing message:  663
# processing message:  664
# processing message:  665
# processing message:  666
# processing message:  667
# processing message:  668
# processing message:  669
# processing message:  670
# processing message:  671
# processing message:  672
# processing message:  673
# processing message:  674
# processing message:  675
# processing message:  676
# processing message:  677
# processing message:  678
# processing message:  679
# processing message:  680
# processing message:  681
# processing message:  682
# processing message:  683
# processing message:  684
# processing message:  685
# processing message:  686
# processing message:  687
# processing message:  688
# processing message:  689
# processing message:  690
# processing message:  691
# processing message:  692
# processing message:  693
# processing message:  694
# processing message:  695
# processing message:  696
# processing message:  697
# processing message:  698
# processing message:  699
# processing message:  700
# processing message:  701
# processing message:  702
# processing message:  703
# processing message:  704
# processing message:  705
# processing message:  706
# processing message:  707
# processing message:  708
# processing message:  709
# processing message:  710
# processing message:  711
# processing message:  712
# processing message:  713
# processing message:  714
# processing message:  715
# processing message:  716
# processing message:  717
# processing message:  718
# processing message:  719
# processing message:  720
# processing message:  721
# processing message:  722
# processing message:  723
# processing message:  724
# processing message:  725
# processing message:  726
# processing message:  727
# processing message:  728
# processing message:  729
# processing message:  730
# processing message:  731
# processing message:  732
# processing message:  733
# processing message:  734
# processing message:  735
# processing message:  736
# processing message:  737
# processing message:  738
# processing message:  739
# processing message:  740
# processing message:  741
# processing message:  742
# processing message:  743
# processing message:  744
# processing message:  745
# processing message:  746
# processing message:  747
# processing message:  748
# processing message:  749
# processing message:  750
# processing message:  751
# processing message:  752
# processing message:  753
# processing message:  754
# processing message:  755
# processing message:  756
# processing message:  757
# processing message:  758
# processing message:  759
# processing message:  760
# processing message:  761
# processing message:  762
# processing message:  763
# processing message:  764
# processing message:  765
# processing message:  766
# processing message:  767
# processing message:  768
# processing message:  769
# processing message:  770
# processing message:  771
# processing message:  772
# processing message:  773
# processing message:  774
# processing message:  775
# processing message:  776
# processing message:  777
# processing message:  778
# processing message:  779
# processing message:  780
# processing message:  781
# processing message:  782
# processing message:  783
# processing message:  784
# processing message:  785
# processing message:  786
# processing message:  787
# processing message:  788
# processing message:  789
# processing message:  790
# processing message:  791
# processing message:  792
# processing message:  793
# processing message:  794
# processing message:  795
# processing message:  796
# processing message:  797
# processing message:  798
# processing message:  799
# processing message:  800
# processing message:  801
# processing message:  802
# processing message:  803
# processing message:  804
# processing message:  805
# processing message:  806
# processing message:  807
# processing message:  808
# processing message:  809
# processing message:  810
# processing message:  811
# processing message:  812
# processing message:  813
# processing message:  814
# processing message:  815
# processing message:  816
# processing message:  817
# processing message:  818
# processing message:  819
# processing message:  820
# processing message:  821
# processing message:  822
# processing message:  823
# processing message:  824
# processing message:  825
# processing message:  826
# processing message:  827
# processing message:  828
# processing message:  829
# processing message:  830
# processing message:  831
# processing message:  832
# processing message:  833
# processing message:  834
# processing message:  835
# processing message:  836
# processing message:  837
# processing message:  838
# processing message:  839
# processing message:  840
# processing message:  841
# processing message:  842
# processing message:  843
# processing message:  844
# processing message:  845
# processing message:  846
# processing message:  847
# processing message:  848
# processing message:  849
# processing message:  850
# processing message:  851
# processing message:  852
# processing message:  853
# processing message:  854
# processing message:  855
# processing message:  856
# processing message:  857
# processing message:  858
# processing message:  859
# processing message:  860
# processing message:  861
# processing message:  862
# processing message:  863
# processing message:  864
# processing message:  865
# processing message:  866
# processing message:  867
# processing message:  868
# processing message:  869
# processing message:  870
# processing message:  871
# processing message:  872
# processing message:  873
# processing message:  874
# processing message:  875
# processing message:  876
# processing message:  877
# processing message:  878
# processing message:  879
# processing message:  880
# processing message:  881
# processing message:  882
# processing message:  883
# processing message:  884
# processing message:  885
# processing message:  886
# processing message:  887
# processing message:  888
# processing message:  889
# processing message:  890
# processing message:  891
# processing message:  892
# processing message:  893
# processing message:  894
# processing message:  895
# processing message:  896
# processing message:  897
# processing message:  898
# processing message:  899
# processing message:  900
# processing message:  901
# processing message:  902
# processing message:  903
# processing message:  904
# processing message:  905
# processing message:  906
# processing message:  907
# processing message:  908
# processing message:  909
# processing message:  910
# processing message:  911
# processing message:  912
# processing message:  913
# processing message:  914
# processing message:  915
# processing message:  916
# processing message:  917
# processing message:  918
# processing message:  919
# processing message:  920
# processing message:  921
# processing message:  922
# processing message:  923
# processing message:  924
# processing message:  925
# processing message:  926
# processing message:  927
# processing message:  928
# processing message:  929
# processing message:  930
# processing message:  931
# processing message:  932
# processing message:  933
# processing message:  934
# processing message:  935
# processing message:  936
# processing message:  937
# processing message:  938
# processing message:  939
# processing message:  940
# processing message:  941
# processing message:  942
# processing message:  943
# processing message:  944
# processing message:  945
# processing message:  946
# processing message:  947
# processing message:  948
# processing message:  949
# processing message:  950
# processing message:  951
# processing message:  952
# processing message:  953
# processing message:  954
# processing message:  955
# processing message:  956
# processing message:  957
# processing message:  958
# processing message:  959
# processing message:  960
# processing message:  961
# processing message:  962
# processing message:  963
# processing message:  964
# processing message:  965
# processing message:  966
# processing message:  967
# processing message:  968
# processing message:  969
# processing message:  970
# processing message:  971
# processing message:  972
# processing message:  973
# processing message:  974
# processing message:  975
# processing message:  976
# processing message:  977
# processing message:  978
# processing message:  979
# processing message:  980
# processing message:  981
# processing message:  982
# processing message:  983
# processing message:  984
# processing message:  985
# processing message:  986
# processing message:  987
# processing message:  988
# processing message:  989
# processing message:  990
# processing message:  991
# processing message:  992
# processing message:  993
# processing message:  994
# processing message:  995
# processing message:  996
# processing message:  997
# processing message:  998
# processing message:  999
# processing message:  1000
# processing message:  1001
# processing message:  1002
# processing message:  1003
# processing message:  1004
# processing message:  1005
# processing message:  1006
# processing message:  1007
# processing message:  1008
# processing message:  1009
# processing message:  1010
# processing message:  1011
# processing message:  1012
# processing message:  1013
# processing message:  1014
# processing message:  1015
# processing message:  1016
# processing message:  1017
# processing message:  1018
# processing message:  1019
# processing message:  1020
# processing message:  1021
# processing message:  1022
# processing message:  1023
# processing message:  1024
# processing message:  1025
# processing message:  1026
# processing message:  1027
# processing message:  1028
# processing message:  1029
# processing message:  1030
# processing message:  1031
# processing message:  1032
# processing message:  1033
# processing message:  1034
# processing message:  1035
# processing message:  1036
# processing message:  1037
# processing message:  1038
# processing message:  1039
# processing message:  1040
# processing message:  1041
# processing message:  1042
# processing message:  1043
# processing message:  1044
# processing message:  1045
# processing message:  1046
# processing message:  1047
# processing message:  1048
# processing message:  1049
# processing message:  1050
# processing message:  1051
# processing message:  1052
# processing message:  1053
# processing message:  1054
# processing message:  1055
# processing message:  1056
# processing message:  1057
# processing message:  1058
# processing message:  1059
# processing message:  1060
# processing message:  1061
# processing message:  1062
# processing message:  1063
# processing message:  1064
# processing message:  1065
# processing message:  1066
# processing message:  1067
# processing message:  1068
# processing message:  1069
# processing message:  1070
# processing message:  1071
# processing message:  1072
# processing message:  1073
# processing message:  1074
# processing message:  1075
# processing message:  1076
# processing message:  1077
# processing message:  1078
# processing message:  1079
# processing message:  1080
# processing message:  1081
# processing message:  1082
# processing message:  1083
# processing message:  1084
# processing message:  1085
# processing message:  1086
# processing message:  1087
# processing message:  1088
# processing message:  1089
# processing message:  1090
# processing message:  1091
# processing message:  1092
# processing message:  1093
# processing message:  1094
# processing message:  1095
# processing message:  1096
# processing message:  1097
# processing message:  1098
# processing message:  1099
# processing message:  1100
# processing message:  1101
# processing message:  1102
# processing message:  1103
# processing message:  1104
# processing message:  1105
# processing message:  1106
# processing message:  1107
# processing message:  1108
# processing message:  1109
# processing message:  1110
# processing message:  1111
# processing message:  1112
# processing message:  1113
# processing message:  1114
# processing message:  1115
# processing message:  1116
# processing message:  1117
# processing message:  1118
# processing message:  1119
# processing message:  1120
# processing message:  1121
# processing message:  1122
# processing message:  1123
# processing message:  1124
# processing message:  1125
# processing message:  1126
# processing message:  1127
# processing message:  1128
# processing message:  1129
# processing message:  1130
# processing message:  1131
# processing message:  1132
# processing message:  1133
# processing message:  1134
# processing message:  1135
# processing message:  1136
# processing message:  1137
# processing message:  1138
# processing message:  1139
# processing message:  1140
# processing message:  1141
# processing message:  1142
# processing message:  1143
# processing message:  1144
# processing message:  1145
# processing message:  1146
# processing message:  1147
# processing message:  1148
# processing message:  1149
# processing message:  1150
# processing message:  1151
# processing message:  1152
# processing message:  1153
# processing message:  1154
# processing message:  1155
# processing message:  1156
# processing message:  1157
# processing message:  1158
# processing message:  1159
# processing message:  1160
# processing message:  1161
# processing message:  1162
# processing message:  1163
# processing message:  1164
# processing message:  1165
# processing message:  1166
# processing message:  1167
# processing message:  1168
# processing message:  1169
# processing message:  1170
# processing message:  1171
# processing message:  1172
# processing message:  1173
# processing message:  1174
# processing message:  1175
# processing message:  1176
# processing message:  1177
# processing message:  1178
# processing message:  1179
# processing message:  1180
# processing message:  1181
# processing message:  1182
# processing message:  1183
# processing message:  1184
# processing message:  1185
# processing message:  1186
# processing message:  1187
# processing message:  1188
# processing message:  1189
# processing message:  1190
# processing message:  1191
# processing message:  1192
# processing message:  1193
# processing message:  1194
# processing message:  1195
# processing message:  1196
# processing message:  1197
# processing message:  1198
# processing message:  1199
# processing message:  1200
# processing message:  1201
# processing message:  1202
# processing message:  1203
# processing message:  1204
# processing message:  1205
# processing message:  1206
# processing message:  1207
# processing message:  1208
# processing message:  1209
# processing message:  1210
# processing message:  1211
# processing message:  1212
# processing message:  1213
# processing message:  1214
# processing message:  1215
# processing message:  1216
# processing message:  1217
# processing message:  1218
# processing message:  1219
# processing message:  1220
# processing message:  1221
# processing message:  1222
# processing message:  1223
# processing message:  1224
# processing message:  1225
# processing message:  1226
# processing message:  1227
# processing message:  1228
# processing message:  1229
# processing message:  1230
# processing message:  1231
# processing message:  1232
# processing message:  1233
# processing message:  1234
# processing message:  1235
# processing message:  1236
# processing message:  1237
# processing message:  1238
# processing message:  1239
# processing message:  1240
# processing message:  1241
# processing message:  1242
# processing message:  1243
# processing message:  1244
# processing message:  1245
# processing message:  1246
# processing message:  1247
# processing message:  1248
# processing message:  1249
# processing message:  1250
# processing message:  1251
# processing message:  1252
# processing message:  1253
# processing message:  1254
# processing message:  1255
# processing message:  1256
# processing message:  1257
# processing message:  1258
# processing message:  1259
# processing message:  1260
# processing message:  1261
# processing message:  1262
# processing message:  1263
# processing message:  1264
# processing message:  1265
# processing message:  1266
# processing message:  1267
# processing message:  1268
# processing message:  1269
# processing message:  1270
# processing message:  1271
# processing message:  1272
# processing message:  1273
# processing message:  1274
# processing message:  1275
# processing message:  1276
# processing message:  1277
# processing message:  1278
# processing message:  1279
# processing message:  1280
# processing message:  1281
# processing message:  1282
# processing message:  1283
# processing message:  1284
# processing message:  1285
# processing message:  1286
# processing message:  1287
# processing message:  1288
# processing message:  1289
# processing message:  1290
# processing message:  1291
# processing message:  1292
# processing message:  1293
# processing message:  1294
# processing message:  1295
# processing message:  1296
# processing message:  1297
# processing message:  1298
# processing message:  1299
# processing message:  1300
# processing message:  1301
# processing message:  1302
# processing message:  1303
# processing message:  1304
# processing message:  1305
# processing message:  1306
# processing message:  1307
# processing message:  1308
# processing message:  1309
# processing message:  1310
# processing message:  1311
# processing message:  1312
# processing message:  1313
# processing message:  1314
# processing message:  1315
# processing message:  1316
# processing message:  1317
# processing message:  1318
# processing message:  1319
# processing message:  1320
# processing message:  1321
# processing message:  1322
# processing message:  1323
# processing message:  1324
# processing message:  1325
# processing message:  1326
# processing message:  1327
# processing message:  1328
# processing message:  1329
# processing message:  1330
# processing message:  1331
# processing message:  1332
# processing message:  1333
# processing message:  1334
# processing message:  1335
# processing message:  1336
# processing message:  1337
# processing message:  1338
# processing message:  1339
# processing message:  1340
# processing message:  1341
# processing message:  1342
# processing message:  1343
# processing message:  1344
# processing message:  1345
# processing message:  1346
# processing message:  1347
# processing message:  1348
# processing message:  1349
# processing message:  1350
# processing message:  1351
# processing message:  1352
# processing message:  1353
# processing message:  1354
# processing message:  1355
# processing message:  1356
# processing message:  1357
# processing message:  1358
# processing message:  1359
# processing message:  1360
# processing message:  1361
# processing message:  1362
# processing message:  1363
# processing message:  1364
# processing message:  1365
# processing message:  1366
# processing message:  1367
# processing message:  1368
# processing message:  1369
# processing message:  1370
# processing message:  1371
# processing message:  1372
# processing message:  1373
# processing message:  1374
# processing message:  1375
# processing message:  1376
# processing message:  1377
# processing message:  1378
# processing message:  1379
# processing message:  1380
# processing message:  1381
# processing message:  1382
# processing message:  1383
# processing message:  1384
# processing message:  1385
# processing message:  1386
# processing message:  1387
# processing message:  1388
# processing message:  1389
# processing message:  1390
# processing message:  1391
# processing message:  1392
# 1393

# %%
false = []
for i in range(len(re)):
    if re[i] != validation_labels[i]:
        false.append((i, re[i], validation_labels[i]))
print("number of false predictions: ", len(false))
print(false)
# Out:
# number of false predictions:  79
# [(22, 0, 1), (40, 0, 1), (63, 0, 1), (83, 0, 1), (100, 0, 1), (107, 0, 1), (140, 0, 1), (143, 0, 1), (148, 0, 1), (172, 0, 1), (189, 0, 1), (192, 0, 1), (205, 0, 1), (208, 0, 1), (217, 0, 1), (278, 0, 1), (302, 0, 1), (324, 0, 1), (369, 0, 1), (387, 0, 1), (391, 0, 1), (426, 0, 1), (462, 0, 1), (500, 0, 1), (507, 0, 1), (533, 0, 1), (538, 0, 1), (541, 0, 1), (549, 0, 1), (559, 0, 1), (560, 0, 1), (589, 0, 1), (591, 0, 1), (596, 0, 1), (611, 0, 1), (624, 0, 1), (699, 0, 1), (706, 0, 1), (708, 0, 1), (718, 0, 1), (753, 0, 1), (793, 0, 1), (835, 0, 1), (840, 0, 1), (868, 0, 1), (886, 0, 1), (896, 0, 1), (912, 0, 1), (927, 0, 1), (931, 0, 1), (945, 0, 1), (983, 0, 1), (986, 0, 1), (993, 0, 1), (1007, 0, 1), (1013, 0, 1), (1028, 0, 1), (1029, 0, 1), (1031, 0, 1), (1077, 0, 1), (1115, 0, 1), (1116, 0, 1), (1122, 0, 1), (1123, 0, 1), (1141, 0, 1), (1166, 0, 1), (1175, 0, 1), (1183, 0, 1), (1248, 0, 1), (1261, 0, 1), (1266, 0, 1), (1282, 0, 1), (1284, 0, 1), (1296, 0, 1), (1322, 0, 1), (1349, 0, 1), (1351, 0, 1), (1369, 0, 1), (1386, 0, 1)]
